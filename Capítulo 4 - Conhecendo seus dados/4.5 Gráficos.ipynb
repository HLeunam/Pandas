# %% [markdown]
# ### 4.5 Gráficos

# %%
#P30 Gráfico de uma função.
import pandas as pd

df = pd.DataFrame({"x": list(range(1,11))}) 
df['2024'] = (df.x * 2) + 3
lines = df.plot.line(x="x", y="2024", legend=True)

# %%
#P31 - Gráfico de linhas.
dados = {
        'óleo de soja': [71.15, 66.93, 67.91, 67.66],
        'melancia': [10.52, 15.68, 14.95, 26.23],
        'frango congelado': [47.17, 23.68, 38.36, 17.08]
        }

df = pd.DataFrame(dados, index=[3,6,9,12])

lines = df.plot(kind ='line',
                style = ['.-', '+-', '*-'],
                ylim=(0,100), xlim=(3,12),
                title="Diferença de vendas ao longo dos meses"
                )

# %% [markdown]
# ### Gráfico de barras

# %%
# P32 Gráfico de barras vertical.
import pandas as pd

df = pd.DataFrame([70, 25, 50], index=['teatro', 'escultura', 'pintura'])

barras = df.plot(kind='bar', legend=True)

# %%
#P33: Gráfico de barras agrupadas.
df = pd.DataFrame({'mulheres': [40, 10, 30],
                    'homens': [30,15,20]},
                    index=['teatro', 'escultura', 'pintura'])
barras = df.plot(kind='bar', legend=True, color=['pink', 'blue'])

# %% [markdown]
# ### Histograma

# %%
#P34: Histograma
import pandas as pd

df = pd.DataFrame({
    'tempo': [4, 5, 1, 7, 7, 8, 6, 6, 5,
              2, 5, 8, 7, 1, 6, 3, 4, 8,
              5, 7, 4, 6, 3, 6, 2, 6, 8]
            })

histograma = df.plot(kind='hist', bins=3)
